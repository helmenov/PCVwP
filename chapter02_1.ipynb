# %%
import numpy as np
from PIL import Image
from pcvwp import harris

# %% [markdown]
# # 2 画像の局所記述子たち
#
# この章では，画像間の対応点・対応領域の検出について議論する．　局所記述子には2つの異なるタイプがあり，画像間を

# %% [markdown]
# # 2.1 Harris Corner Detector

# %%
im = np.array(Image.open('data/empire.jpg').convert('L'))
harrisim = harris.compute_harris_response(im)
filtered_coords = harris.get_harris_points(harrisim=harrisim,min_dist=6,threshold=0.1)
fig2_1 = harris.plot_harris_points(im, filtered_coords)

# %% [markdown]
# ## Finding Corresponding Points Between Images
